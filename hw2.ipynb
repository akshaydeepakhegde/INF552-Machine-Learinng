# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
# %matplotlib inline
from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 15, 6

# %%
data_bend1_test1 = pd.read_csv('C:/Users/aksha/Downloads/INF552/hw/AReM/bending1/test_data/dataset1.csv',skiprows=4,error_bad_lines=False)
data_bend1_test2 = pd.read_csv('C:/Users/aksha/Downloads/INF552/hw/AReM/bending1/test_data/dataset2.csv',skiprows=4,error_bad_lines=False)

data_bend2_test1 = pd.read_csv('C:/Users/aksha/Downloads/INF552/hw/AReM/bending2/test_data/dataset1.csv',skiprows=4,error_bad_lines=False)
data_bend2_test2 = pd.read_csv('C:/Users/aksha/Downloads/INF552/hw/AReM/bending2/test_data/dataset2.csv',skiprows=4,error_bad_lines=False)

data_cycling_test1 = pd.read_csv('C:/Users/aksha/Downloads/INF552/hw/AReM/cycling/test_data/dataset1.csv',skiprows=4,error_bad_lines=False)
data_cycling_test2 = pd.read_csv('C:/Users/aksha/Downloads/INF552/hw/AReM/cycling/test_data/dataset2.csv',skiprows=4,error_bad_lines=False)
data_cycling_test3 = pd.read_csv('C:/Users/aksha/Downloads/INF552/hw/AReM/cycling/test_data/dataset3.csv',skiprows=4,error_bad_lines=False)

data_lying_test1 = pd.read_csv('C:/Users/aksha/Downloads/INF552/hw/AReM/lying/test_data/dataset1.csv',skiprows=4,error_bad_lines=False)
data_lying_test2 = pd.read_csv('C:/Users/aksha/Downloads/INF552/hw/AReM/lying/test_data/dataset2.csv',skiprows=4,error_bad_lines=False)
data_lying_test3 = pd.read_csv('C:/Users/aksha/Downloads/INF552/hw/AReM/lying/test_data/dataset3.csv',skiprows=4,error_bad_lines=False)

data_sitting_test1 = pd.read_csv('C:/Users/aksha/Downloads/INF552/hw/AReM/sitting/test_data/dataset1.csv',skiprows=4,error_bad_lines=False)
data_sitting_test2 = pd.read_csv('C:/Users/aksha/Downloads/INF552/hw/AReM/sitting/test_data/dataset2.csv',skiprows=4,error_bad_lines=False)
data_sitting_test3 = pd.read_csv('C:/Users/aksha/Downloads/INF552/hw/AReM/sitting/test_data/dataset3.csv',skiprows=4,error_bad_lines=False)

data_standing_test1 = pd.read_csv('C:/Users/aksha/Downloads/INF552/hw/AReM/standing/test_data/dataset1.csv',skiprows=4,error_bad_lines=False)
data_standing_test2 = pd.read_csv('C:/Users/aksha/Downloads/INF552/hw/AReM/standing/test_data/dataset2.csv',skiprows=4,error_bad_lines=False)
data_standing_test3 = pd.read_csv('C:/Users/aksha/Downloads/INF552/hw/AReM/standing/test_data/dataset3.csv',skiprows=4,error_bad_lines=False)

data_walking_test1 = pd.read_csv('C:/Users/aksha/Downloads/INF552/hw/AReM/walking/test_data/dataset1.csv',skiprows=4,error_bad_lines=False)
data_walking_test2 = pd.read_csv('C:/Users/aksha/Downloads/INF552/hw/AReM/walking/test_data/dataset2.csv',skiprows=4,error_bad_lines=False)
data_walking_test3 = pd.read_csv('C:/Users/aksha/Downloads/INF552/hw/AReM/walking/test_data/dataset3.csv',skiprows=4,error_bad_lines=False)

# %%
data_walking_test3.head(4)
# Out:
#    # Columns: time  avg_rss12  var_rss12  avg_rss13  var_rss13  avg_rss23  \
# 0                0      24.75       5.76      13.25       3.03      18.75
# 1              250      36.25       7.26      15.00       3.67      17.75
# 2              500      37.00       3.94      20.25       1.30      16.25
# 3              750      33.75       3.27      19.50       4.50      15.00
#
#    var_rss23
# 0       1.48
# 1       2.86
# 2       1.64
# 3       2.12

# %%
data_bend1_train1 = pd.read_csv('C:/Users/aksha/Downloads/INF552/hw/AReM/bending1/train_data/dataset3.csv',skiprows=4,error_bad_lines=False)
data_bend1_train2 = pd.read_csv('C:/Users/aksha/Downloads/INF552/hw/AReM/bending1/train_data/dataset4.csv',skiprows=4,error_bad_lines=False)
data_bend1_train3 = pd.read_csv('C:/Users/aksha/Downloads/INF552/hw/AReM/bending1/train_data/dataset5.csv',skiprows=4,error_bad_lines=False)
data_bend1_train4 = pd.read_csv('C:/Users/aksha/Downloads/INF552/hw/AReM/bending1/train_data/dataset6.csv',skiprows=4,error_bad_lines=False)
data_bend1_train5 = pd.read_csv('C:/Users/aksha/Downloads/INF552/hw/AReM/bending1/train_data/dataset7.csv',skiprows=4,error_bad_lines=False)


data_bend2_train6 = pd.read_csv('C:/Users/aksha/Downloads/INF552/hw/AReM/bending2/train_data/dataset3.csv',skiprows=4,error_bad_lines=False)
data_bend2_train7 = pd.read_csv('C:/Users/aksha/Downloads/INF552/hw/AReM/bending2/train_data/dataset4.csv',skiprows=4,error_bad_lines=False)
data_bend2_train8 = pd.read_csv('C:/Users/aksha/Downloads/INF552/hw/AReM/bending2/train_data/dataset5.csv',skiprows=4,error_bad_lines=False)
data_bend2_train9 = pd.read_csv('C:/Users/aksha/Downloads/INF552/hw/AReM/bending2/train_data/dataset6.csv',skiprows=4,error_bad_lines=False)

# %%
data_cycling_train10 = pd.read_csv('C:/Users/aksha/Downloads/INF552/hw/AReM/cycling/train_data/dataset4.csv',skiprows=4,error_bad_lines=False)
data_cycling_train11 = pd.read_csv('C:/Users/aksha/Downloads/INF552/hw/AReM/cycling/train_data/dataset5.csv',skiprows=4,error_bad_lines=False)
data_cycling_train12 = pd.read_csv('C:/Users/aksha/Downloads/INF552/hw/AReM/cycling/train_data/dataset6.csv',skiprows=4,error_bad_lines=False)
data_cycling_train13 = pd.read_csv('C:/Users/aksha/Downloads/INF552/hw/AReM/cycling/train_data/dataset7.csv',skiprows=4,error_bad_lines=False)
data_cycling_train14 = pd.read_csv('C:/Users/aksha/Downloads/INF552/hw/AReM/cycling/train_data/dataset8.csv',skiprows=4,error_bad_lines=False)
data_cycling_train15 = pd.read_csv('C:/Users/aksha/Downloads/INF552/hw/AReM/cycling/train_data/dataset9.csv',skiprows=4,error_bad_lines=False)
data_cycling_train16 = pd.read_csv('C:/Users/aksha/Downloads/INF552/hw/AReM/cycling/train_data/dataset10.csv',skiprows=4,error_bad_lines=False)
data_cycling_train17 = pd.read_csv('C:/Users/aksha/Downloads/INF552/hw/AReM/cycling/train_data/dataset11.csv',skiprows=4,error_bad_lines=False)
data_cycling_train18 = pd.read_csv('C:/Users/aksha/Downloads/INF552/hw/AReM/cycling/train_data/dataset12.csv',skiprows=4,error_bad_lines=False)

# %%
data_cycling_train19 = pd.read_csv('C:/Users/aksha/Downloads/INF552/hw/AReM/cycling/train_data/dataset13.csv',skiprows=4,error_bad_lines=False)
data_cycling_train20 = pd.read_csv('C:/Users/aksha/Downloads/INF552/hw/AReM/cycling/train_data/dataset14.csv',skiprows=4,error_bad_lines=False)
data_cycling_train21 = pd.read_csv('C:/Users/aksha/Downloads/INF552/hw/AReM/cycling/train_data/dataset15.csv',skiprows=4,error_bad_lines=False)
data_lying_train22 = pd.read_csv('C:/Users/aksha/Downloads/INF552/hw/AReM/lying/train_data/dataset4.csv',skiprows=4,error_bad_lines=False)
data_lying_train23 = pd.read_csv('C:/Users/aksha/Downloads/INF552/hw/AReM/lying/train_data/dataset5.csv',skiprows=4,error_bad_lines=False)
data_lying_train24 = pd.read_csv('C:/Users/aksha/Downloads/INF552/hw/AReM/lying/train_data/dataset6.csv',skiprows=4,error_bad_lines=False)
data_lying_train25 = pd.read_csv('C:/Users/aksha/Downloads/INF552/hw/AReM/lying/train_data/dataset7.csv',skiprows=4,error_bad_lines=False)
data_lying_train26 = pd.read_csv('C:/Users/aksha/Downloads/INF552/hw/AReM/lying/train_data/dataset8.csv',skiprows=4,error_bad_lines=False)
data_lying_train27 = pd.read_csv('C:/Users/aksha/Downloads/INF552/hw/AReM/lying/train_data/dataset9.csv',skiprows=4,error_bad_lines=False)
data_lying_train28 = pd.read_csv('C:/Users/aksha/Downloads/INF552/hw/AReM/lying/train_data/dataset10.csv',skiprows=4,error_bad_lines=False)
data_lying_train29 = pd.read_csv('C:/Users/aksha/Downloads/INF552/hw/AReM/lying/train_data/dataset11.csv',skiprows=4,error_bad_lines=False)
data_lying_train30 = pd.read_csv('C:/Users/aksha/Downloads/INF552/hw/AReM/lying/train_data/dataset12.csv',skiprows=4,error_bad_lines=False)
data_lying_train31 = pd.read_csv('C:/Users/aksha/Downloads/INF552/hw/AReM/lying/train_data/dataset13.csv',skiprows=4,error_bad_lines=False)
data_lying_train32 = pd.read_csv('C:/Users/aksha/Downloads/INF552/hw/AReM/lying/train_data/dataset14.csv',skiprows=4,error_bad_lines=False)
data_lying_train33 = pd.read_csv('C:/Users/aksha/Downloads/INF552/hw/AReM/lying/train_data/dataset15.csv',skiprows=4,error_bad_lines=False)


data_sitting_train34 = pd.read_csv('C:/Users/aksha/Downloads/INF552/hw/AReM/sitting/train_data/dataset4.csv',skiprows=4,error_bad_lines=False)
data_sitting_train35 = pd.read_csv('C:/Users/aksha/Downloads/INF552/hw/AReM/sitting/train_data/dataset5.csv',skiprows=4,error_bad_lines=False)
data_sitting_train36 = pd.read_csv('C:/Users/aksha/Downloads/INF552/hw/AReM/sitting/train_data/dataset6.csv',skiprows=4,error_bad_lines=False)
data_sitting_train37 = pd.read_csv('C:/Users/aksha/Downloads/INF552/hw/AReM/sitting/train_data/dataset7.csv',skiprows=4,error_bad_lines=False)
data_sitting_train38 = pd.read_csv('C:/Users/aksha/Downloads/INF552/hw/AReM/sitting/train_data/dataset8.csv',skiprows=4,error_bad_lines=False)
data_sitting_train39 = pd.read_csv('C:/Users/aksha/Downloads/INF552/hw/AReM/sitting/train_data/dataset9.csv',skiprows=4,error_bad_lines=False)
data_sitting_train40 = pd.read_csv('C:/Users/aksha/Downloads/INF552/hw/AReM/sitting/train_data/dataset10.csv',skiprows=4,error_bad_lines=False)
data_sitting_train41 = pd.read_csv('C:/Users/aksha/Downloads/INF552/hw/AReM/sitting/train_data/dataset11.csv',skiprows=4,error_bad_lines=False)
data_sitting_train42 = pd.read_csv('C:/Users/aksha/Downloads/INF552/hw/AReM/sitting/train_data/dataset12.csv',skiprows=4,error_bad_lines=False)
data_sitting_train43 = pd.read_csv('C:/Users/aksha/Downloads/INF552/hw/AReM/sitting/train_data/dataset13.csv',skiprows=4,error_bad_lines=False)
data_sitting_train44 = pd.read_csv('C:/Users/aksha/Downloads/INF552/hw/AReM/sitting/train_data/dataset14.csv',skiprows=4,error_bad_lines=False)
data_sitting_train45 = pd.read_csv('C:/Users/aksha/Downloads/INF552/hw/AReM/sitting/train_data/dataset15.csv',skiprows=4,error_bad_lines=False)

data_standing_train46 = pd.read_csv('C:/Users/aksha/Downloads/INF552/hw/AReM/standing/train_data/dataset4.csv',skiprows=4,error_bad_lines=False)
data_standing_train47 = pd.read_csv('C:/Users/aksha/Downloads/INF552/hw/AReM/standing/train_data/dataset5.csv',skiprows=4,error_bad_lines=False)
data_standing_train48 = pd.read_csv('C:/Users/aksha/Downloads/INF552/hw/AReM/standing/train_data/dataset6.csv',skiprows=4,error_bad_lines=False)
data_standing_train49 = pd.read_csv('C:/Users/aksha/Downloads/INF552/hw/AReM/standing/train_data/dataset7.csv',skiprows=4,error_bad_lines=False)
data_standing_train50 = pd.read_csv('C:/Users/aksha/Downloads/INF552/hw/AReM/standing/train_data/dataset8.csv',skiprows=4,error_bad_lines=False)
data_standing_train51 = pd.read_csv('C:/Users/aksha/Downloads/INF552/hw/AReM/standing/train_data/dataset9.csv',skiprows=4,error_bad_lines=False)
data_standing_train52 = pd.read_csv('C:/Users/aksha/Downloads/INF552/hw/AReM/standing/train_data/dataset10.csv',skiprows=4,error_bad_lines=False)
data_standing_train53 = pd.read_csv('C:/Users/aksha/Downloads/INF552/hw/AReM/standing/train_data/dataset11.csv',skiprows=4,error_bad_lines=False)
data_standing_train54 = pd.read_csv('C:/Users/aksha/Downloads/INF552/hw/AReM/standing/train_data/dataset12.csv',skiprows=4,error_bad_lines=False)
data_standing_train55 = pd.read_csv('C:/Users/aksha/Downloads/INF552/hw/AReM/standing/train_data/dataset13.csv',skiprows=4,error_bad_lines=False)
data_standing_train56 = pd.read_csv('C:/Users/aksha/Downloads/INF552/hw/AReM/standing/train_data/dataset14.csv',skiprows=4,error_bad_lines=False)
data_standing_train57 = pd.read_csv('C:/Users/aksha/Downloads/INF552/hw/AReM/standing/train_data/dataset15.csv',skiprows=4,error_bad_lines=False)

data_walking_train58 = pd.read_csv('C:/Users/aksha/Downloads/INF552/hw/AReM/walking/train_data/dataset4.csv',skiprows=4,error_bad_lines=False)
data_walking_train59 = pd.read_csv('C:/Users/aksha/Downloads/INF552/hw/AReM/walking/train_data/dataset5.csv',skiprows=4,error_bad_lines=False)
data_walking_train60 = pd.read_csv('C:/Users/aksha/Downloads/INF552/hw/AReM/walking/train_data/dataset6.csv',skiprows=4,error_bad_lines=False)
data_walking_train61 = pd.read_csv('C:/Users/aksha/Downloads/INF552/hw/AReM/walking/train_data/dataset7.csv',skiprows=4,error_bad_lines=False)
data_walking_train62 = pd.read_csv('C:/Users/aksha/Downloads/INF552/hw/AReM/walking/train_data/dataset8.csv',skiprows=4,error_bad_lines=False)
data_walking_train63 = pd.read_csv('C:/Users/aksha/Downloads/INF552/hw/AReM/walking/train_data/dataset9.csv',skiprows=4,error_bad_lines=False)
data_walking_train64 = pd.read_csv('C:/Users/aksha/Downloads/INF552/hw/AReM/walking/train_data/dataset10.csv',skiprows=4,error_bad_lines=False)
data_walking_train65 = pd.read_csv('C:/Users/aksha/Downloads/INF552/hw/AReM/walking/train_data/dataset11.csv',skiprows=4,error_bad_lines=False)
data_walking_train66 = pd.read_csv('C:/Users/aksha/Downloads/INF552/hw/AReM/walking/train_data/dataset12.csv',skiprows=4,error_bad_lines=False)
data_walking_train67 = pd.read_csv('C:/Users/aksha/Downloads/INF552/hw/AReM/walking/train_data/dataset13.csv',skiprows=4,error_bad_lines=False)
data_walking_train68 = pd.read_csv('C:/Users/aksha/Downloads/INF552/hw/AReM/walking/train_data/dataset14.csv',skiprows=4,error_bad_lines=False)
data_walking_train69 = pd.read_csv('C:/Users/aksha/Downloads/INF552/hw/AReM/walking/train_data/dataset15.csv',skiprows=4,error_bad_lines=False)

# %%
d_min_1 = data_bend1_test1.min()
d_min_2 = data_bend1_test2.min()
d_min_3 = data_bend2_test1.min()
d_min_4 = data_bend2_test2.min()
d_min_5 = data_cycling_test1.min()
d_min_6 = data_cycling_test2.min()
d_min_7 = data_cycling_test3.min()
d_min_8 = data_lying_test1.min()
d_min_9 = data_lying_test2.min()
d_min_10 = data_lying_test3.min()
d_min_11 = data_sitting_test1.min()
d_min_12 = data_sitting_test2.min()
d_min_13 = data_sitting_test3.min()
d_min_14 = data_standing_test1.min()
d_min_15 = data_standing_test2.min()
d_min_16 = data_standing_test3.min()
d_min_17 = data_walking_test1.min()
d_min_18 = data_walking_test2.min()
d_min_19 = data_walking_test3.min()
print (d_min_1)
print (d_min_1[1])
#print len(d_min_1)
#print d_min_1[1]
# Out:
# # Columns: time     0.00
# avg_rss12          37.25
# var_rss12           0.00
# avg_rss13           4.00
# var_rss13           0.00
# avg_rss23          27.25
# var_rss23           0.00
# dtype: float64
# 37.25

# %%
d_max_1 = data_bend1_test1.max()
d_max_2 = data_bend1_test2.max()
d_max_3 = data_bend2_test1.max()
d_max_4 = data_bend2_test2.max()
d_max_5 = data_cycling_test1.max()
d_max_6 = data_cycling_test2.max()
d_max_7 = data_cycling_test3.max()
d_max_8 = data_lying_test1.max()
d_max_9 = data_lying_test2.max()
d_max_10 = data_lying_test3.max()
d_max_11 = data_sitting_test1.max()
d_max_12 = data_sitting_test2.max()
d_max_13 = data_sitting_test3.max()
d_max_14 = data_standing_test1.max()
d_max_15 = data_standing_test2.max()
d_max_16 = data_standing_test3.max()
d_max_17 = data_walking_test1.max()
d_max_18 = data_walking_test2.max()
d_max_19 = data_walking_test3.max()
print (d_max_10)
# Out:
# # Columns: time    119750.00
# avg_rss12              48.25
# var_rss12               0.43
# avg_rss13              13.00
# var_rss13               2.86
# avg_rss23              12.00
# var_rss23               2.50
# dtype: float64

# %%
d_mean_1 = data_bend1_test1.mean()
d_mean_2 = data_bend1_test2.mean()
d_mean_3 = data_bend2_test1.mean()
d_mean_4 = data_bend2_test2.mean()
d_mean_5 = data_cycling_test1.mean()
d_mean_6 = data_cycling_test2.mean()
d_mean_7 = data_cycling_test3.mean()
d_mean_8 = data_lying_test1.mean()
d_mean_9 = data_lying_test2.mean()
d_mean_10 = data_lying_test3.mean()
d_mean_11 = data_sitting_test1.mean()
d_mean_12 = data_sitting_test2.mean()
d_mean_13 = data_sitting_test3.mean()
d_mean_14 = data_standing_test1.mean()
d_mean_15 = data_standing_test2.mean()
d_mean_16 = data_standing_test3.mean()
d_mean_17 = data_walking_test1.mean()
d_mean_18 = data_walking_test2.mean()
d_mean_19 = data_walking_test3.mean()
#print type (d_mean_19)
print (d_mean_1)
# Out:
# # Columns: time    59875.000000
# avg_rss12             40.624792
# var_rss12              0.358604
# avg_rss13             19.040937
# var_rss13              0.832542
# avg_rss23             34.311292
# var_rss23              0.570583
# dtype: float64

# %%
rows =[]
total_columns =['min_avg_rss12','min_var_rss12','min_avg_rss13','min_var_rss13','min_avg_rss23','min_var_rss23','max_avg_rss12','max_var_rss12','max_avg_rss13','max_var_rss13','max_avg_rss23','max_var_rss23','mean_avg_rss12','mean_var_rss12','mean_avg_rss13','mean_var_rss13','mean_avg_rss23','mean_var_rss23']

# %%
for i in range(1,7):
    r=d_min_1[i]
    print (r)
    rows.append(r)
print (rows)
print (len(rows))
# Out:
# 37.25
# 0.0
# 4.0
# 0.0
# 27.25
# 0.0
# [37.25, 0.0, 4.0, 0.0, 27.25, 0.0]
# 6

# %%
for i in range(1,7):
    r=d_max_1[i]
    print (r)
    rows.append(r)   
print (rows)
# Out:
# 45.0
# 1.3
# 29.5
# 7.23
# 38.25
# 1.92
# [37.25, 0.0, 4.0, 0.0, 27.25, 0.0, 45.0, 1.3, 29.5, 7.23, 38.25, 1.92]

# %%
for i in range(1,7):
    r=d_mean_1[i]
    print (r)
    rows.append(r) 

print (rows)
# Out:
# 40.62479166666665
# 0.35860416666666745
# 19.0409375
# 0.8325416666666676
# 34.31129166666666
# 0.5705833333333344
# [37.25, 0.0, 4.0, 0.0, 27.25, 0.0, 45.0, 1.3, 29.5, 7.23, 38.25, 1.92, 40.62479166666665, 0.35860416666666745, 19.0409375, 0.8325416666666676, 34.31129166666666, 0.5705833333333344]

# %%
dataframe_test = pd.DataFrame(columns=total_columns)
print (dataframe_test)
dataframe_test.shape
# Out:
# Empty DataFrame
# Columns: [min_avg_rss12, min_var_rss12, min_avg_rss13, min_var_rss13, min_avg_rss23, min_var_rss23, max_avg_rss12, max_var_rss12, max_avg_rss13, max_var_rss13, max_avg_rss23, max_var_rss23, mean_avg_rss12, mean_var_rss12, mean_avg_rss13, mean_var_rss13, mean_avg_rss23, mean_var_rss23]
# Index: []
# (0, 18)

# %%
dataframe_test.loc[0] = rows
display(dataframe_test)
# Out:
#    min_avg_rss12  min_var_rss12  min_avg_rss13  min_var_rss13  min_avg_rss23  \
# 0          37.25            0.0            4.0            0.0          27.25
#
#    min_var_rss23  max_avg_rss12  max_var_rss12  max_avg_rss13  max_var_rss13  \
# 0            0.0           45.0            1.3           29.5           7.23
#
#    max_avg_rss23  max_var_rss23  mean_avg_rss12  mean_var_rss12  \
# 0          38.25           1.92       40.624792        0.358604
#
#    mean_avg_rss13  mean_var_rss13  mean_avg_rss23  mean_var_rss23
# 0       19.040937        0.832542       34.311292        0.570583

# %%
array1 = [[(eval('d_min_'+str(x)))[1:],eval('d_max_'+str(x))[1:],eval('d_mean_'+str(x))[1:]] for x in range(1,20)]
#print array1[0]
print (array1[0])
print (len(array1[0]))

#print type(array1)
# Out:
# [avg_rss12    37.25
# var_rss12     0.00
# avg_rss13     4.00
# var_rss13     0.00
# avg_rss23    27.25
# var_rss23     0.00
# dtype: float64, avg_rss12    45.00
# var_rss12     1.30
# avg_rss13    29.50
# var_rss13     7.23
# avg_rss23    38.25
# var_rss23     1.92
# dtype: float64, avg_rss12    40.624792
# var_rss12     0.358604
# avg_rss13    19.040937
# var_rss13     0.832542
# avg_rss23    34.311292
# var_rss23     0.570583
# dtype: float64]
# 3

# %%
import itertools
from IPython.display import display, HTML
for i in range(0,19):
    #print i
    dataframe_test.loc[i] = list(itertools.chain.from_iterable(array1[i]))
display(dataframe_test) 
dataframe_test.shape
# Out:
#     min_avg_rss12  min_var_rss12  min_avg_rss13  min_var_rss13  min_avg_rss23  \
# 0           37.25            0.0           4.00            0.0          27.25
# 1           38.00            0.0           2.00            0.0          27.67
# 2           12.75            0.0           0.00            0.0          10.67
# 3            0.00            0.0           7.50            0.0           0.00
# 4           24.25            0.0           5.50            0.0           7.00
# 5           28.75            0.0           6.50            0.0          10.50
# 6           22.00            0.0           6.33            0.0           7.50
# 7           23.50            0.0           0.00            0.0           0.00
# 8           24.75            0.0           1.00            0.0           0.00
# 9           48.00            0.0           0.00            0.0           0.00
# 10          33.25            0.0           3.00            0.0           1.00
# ...

# %%
d_min_train_1 = data_bend1_train1.min()
d_min_train_2 = data_bend1_train2.min()
d_min_train_3 = data_bend1_train3.min()
d_min_train_4 = data_bend1_train4.min()
d_min_train_5 = data_bend1_train5.min()

d_min_train_6 = data_bend2_train6.min()
d_min_train_7 = data_bend2_train7.min()
d_min_train_8 = data_bend2_train8.min()
d_min_train_9 = data_bend2_train9.min()

d_min_train_10 = data_cycling_train10.min()
d_min_train_11 = data_cycling_train11.min()
d_min_train_12 = data_cycling_train12.min()
d_min_train_13 = data_cycling_train13.min()
d_min_train_14 = data_cycling_train14.min()
d_min_train_15 = data_cycling_train15.min()
d_min_train_16 = data_cycling_train16.min()
d_min_train_17 = data_cycling_train17.min()
d_min_train_18 = data_cycling_train18.min()
d_min_train_19 = data_cycling_train19.min()
d_min_train_20 = data_cycling_train20.min()
d_min_train_21 = data_cycling_train21.min()


d_min_train_22 = data_lying_train22.min()
d_min_train_23 = data_lying_train23.min()
d_min_train_24 = data_lying_train24.min()
d_min_train_25 = data_lying_train25.min()
d_min_train_26 = data_lying_train26.min()
d_min_train_27 = data_lying_train27.min()
d_min_train_28 = data_lying_train28.min()
d_min_train_29 = data_lying_train29.min()
d_min_train_30 = data_lying_train30.min()
d_min_train_31 = data_lying_train31.min()
d_min_train_32 = data_lying_train32.min()
d_min_train_33 = data_lying_train33.min()


d_min_train_34 = data_sitting_train34.min()
d_min_train_35 = data_sitting_train35.min()
d_min_train_36 = data_sitting_train36.min()
d_min_train_37 = data_sitting_train37.min()
d_min_train_38 = data_sitting_train38.min()
d_min_train_39 = data_sitting_train39.min()
d_min_train_40 = data_sitting_train40.min()
d_min_train_41 = data_sitting_train41.min()
d_min_train_42 = data_sitting_train42.min()
d_min_train_43 = data_sitting_train43.min()
d_min_train_44 = data_sitting_train44.min()
d_min_train_45 = data_sitting_train45.min()

d_min_train_46 = data_standing_train46.min()
d_min_train_47 = data_standing_train47.min()
d_min_train_48 = data_standing_train48.min()
d_min_train_49 = data_standing_train49.min()
d_min_train_50 = data_standing_train50.min()
d_min_train_51 = data_standing_train51.min()
d_min_train_52 = data_standing_train52.min()
d_min_train_53 = data_standing_train53.min()
d_min_train_54 = data_standing_train54.min()
d_min_train_55 = data_standing_train55.min()
d_min_train_56 = data_standing_train56.min()
d_min_train_57 = data_standing_train57.min()

d_min_train_58 = data_walking_train58.min()
d_min_train_59 = data_walking_train59.min()
d_min_train_60 = data_walking_train60.min()
d_min_train_61 = data_walking_train61.min()
d_min_train_62 = data_walking_train62.min()
d_min_train_63 = data_walking_train63.min()
d_min_train_64 = data_walking_train64.min()
d_min_train_65 = data_walking_train65.min()
d_min_train_66 = data_walking_train66.min()
d_min_train_67 = data_walking_train67.min()
d_min_train_68 = data_walking_train68.min()
d_min_train_69 = data_walking_train69.min()

# %%
d_max_train_1 = data_bend1_train1.max()
d_max_train_2 = data_bend1_train2.max()
d_max_train_3 = data_bend1_train3.max()
d_max_train_4 = data_bend1_train4.max()
d_max_train_5 = data_bend1_train5.max()

d_max_train_6 = data_bend2_train6.max()
d_max_train_7 = data_bend2_train7.max()
d_max_train_8 = data_bend2_train8.max()
d_max_train_9 = data_bend2_train9.max()

d_max_train_10 = data_cycling_train10.max()
d_max_train_11 = data_cycling_train11.max()
d_max_train_12 = data_cycling_train12.max()
d_max_train_13 = data_cycling_train13.max()
d_max_train_14 = data_cycling_train14.max()
d_max_train_15 = data_cycling_train15.max()
d_max_train_16 = data_cycling_train16.max()
d_max_train_17 = data_cycling_train17.max()
d_max_train_18 = data_cycling_train18.max()
d_max_train_19 = data_cycling_train19.max()
d_max_train_20 = data_cycling_train20.max()
d_max_train_21 = data_cycling_train21.max()


d_max_train_22 = data_lying_train22.max()
d_max_train_23 = data_lying_train23.max()
d_max_train_24 = data_lying_train24.max()
d_max_train_25 = data_lying_train25.max()
d_max_train_26 = data_lying_train26.max()
d_max_train_27 = data_lying_train27.max()
d_max_train_28 = data_lying_train28.max()
d_max_train_29 = data_lying_train29.max()
d_max_train_30 = data_lying_train30.max()
d_max_train_31 = data_lying_train31.max()
d_max_train_32 = data_lying_train32.max()
d_max_train_33 = data_lying_train33.max()


d_max_train_34 = data_sitting_train34.max()
d_max_train_35 = data_sitting_train35.max()
d_max_train_36 = data_sitting_train36.max()
d_max_train_37 = data_sitting_train37.max()
d_max_train_38 = data_sitting_train38.max()
d_max_train_39 = data_sitting_train39.max()
d_max_train_40 = data_sitting_train40.max()
d_max_train_41 = data_sitting_train41.max()
d_max_train_42 = data_sitting_train42.max()
d_max_train_43 = data_sitting_train43.max()
d_max_train_44 = data_sitting_train44.max()
d_max_train_45 = data_sitting_train45.max()

d_max_train_46 = data_standing_train46.max()
d_max_train_47 = data_standing_train47.max()
d_max_train_48 = data_standing_train48.max()
d_max_train_49 = data_standing_train49.max()
d_max_train_50 = data_standing_train50.max()
d_max_train_51 = data_standing_train51.max()
d_max_train_52 = data_standing_train52.max()
d_max_train_53 = data_standing_train53.max()
d_max_train_54 = data_standing_train54.max()
d_max_train_55 = data_standing_train55.max()
d_max_train_56 = data_standing_train56.max()
d_max_train_57 = data_standing_train57.max()

d_max_train_58 = data_walking_train58.max()
d_max_train_59 = data_walking_train59.max()
d_max_train_60 = data_walking_train60.max()
d_max_train_61 = data_walking_train61.max()
d_max_train_62 = data_walking_train62.max()
d_max_train_63 = data_walking_train63.max()
d_max_train_64 = data_walking_train64.max()
d_max_train_65 = data_walking_train65.max()
d_max_train_66 = data_walking_train66.max()
d_max_train_67 = data_walking_train67.max()
d_max_train_68 = data_walking_train68.max()
d_max_train_69 = data_walking_train69.max()

# %%
d_mean_train_1 = data_bend1_train1.mean()
d_mean_train_2 = data_bend1_train2.mean()
d_mean_train_3 = data_bend1_train3.mean()
d_mean_train_4 = data_bend1_train4.mean()
d_mean_train_5 = data_bend1_train5.mean()

d_mean_train_6 = data_bend2_train6.mean()
d_mean_train_7 = data_bend2_train7.mean()
d_mean_train_8 = data_bend2_train8.mean()
d_mean_train_9 = data_bend2_train9.mean()

d_mean_train_10 = data_cycling_train10.mean()
d_mean_train_11 = data_cycling_train11.mean()
d_mean_train_12 = data_cycling_train12.mean()
d_mean_train_13 = data_cycling_train13.mean()
d_mean_train_14 = data_cycling_train14.mean()
d_mean_train_15 = data_cycling_train15.mean()
d_mean_train_16 = data_cycling_train16.mean()
d_mean_train_17 = data_cycling_train17.mean()
d_mean_train_18 = data_cycling_train18.mean()
d_mean_train_19 = data_cycling_train19.mean()
d_mean_train_20 = data_cycling_train20.mean()
d_mean_train_21 = data_cycling_train21.mean()


d_mean_train_22 = data_lying_train22.mean()
d_mean_train_23 = data_lying_train23.mean()
d_mean_train_24 = data_lying_train24.mean()
d_mean_train_25 = data_lying_train25.mean()
d_mean_train_26 = data_lying_train26.mean()
d_mean_train_27 = data_lying_train27.mean()
d_mean_train_28 = data_lying_train28.mean()
d_mean_train_29 = data_lying_train29.mean()
d_mean_train_30 = data_lying_train30.mean()
d_mean_train_31 = data_lying_train31.mean()
d_mean_train_32 = data_lying_train32.mean()
d_mean_train_33 = data_lying_train33.mean()


d_mean_train_34 = data_sitting_train34.mean()
d_mean_train_35 = data_sitting_train35.mean()
d_mean_train_36 = data_sitting_train36.mean()
d_mean_train_37 = data_sitting_train37.mean()
d_mean_train_38 = data_sitting_train38.mean()
d_mean_train_39 = data_sitting_train39.mean()
d_mean_train_40 = data_sitting_train40.mean()
d_mean_train_41 = data_sitting_train41.mean()
d_mean_train_42 = data_sitting_train42.mean()
d_mean_train_43 = data_sitting_train43.mean()
d_mean_train_44 = data_sitting_train44.mean()
d_mean_train_45 = data_sitting_train45.mean()

d_mean_train_46 = data_standing_train46.mean()
d_mean_train_47 = data_standing_train47.mean()
d_mean_train_48 = data_standing_train48.mean()
d_mean_train_49 = data_standing_train49.mean()
d_mean_train_50 = data_standing_train50.mean()
d_mean_train_51 = data_standing_train51.mean()
d_mean_train_52 = data_standing_train52.mean()
d_mean_train_53 = data_standing_train53.mean()
d_mean_train_54 = data_standing_train54.mean()
d_mean_train_55 = data_standing_train55.mean()
d_mean_train_56 = data_standing_train56.mean()
d_mean_train_57 = data_standing_train57.mean()

d_mean_train_58 = data_walking_train58.mean()
d_mean_train_59 = data_walking_train59.mean()
d_mean_train_60 = data_walking_train60.mean()
d_mean_train_61 = data_walking_train61.mean()
d_mean_train_62 = data_walking_train62.mean()
d_mean_train_63 = data_walking_train63.mean()
d_mean_train_64 = data_walking_train64.mean()
d_mean_train_65 = data_walking_train65.mean()
d_mean_train_66 = data_walking_train66.mean()
d_mean_train_67 = data_walking_train67.mean()
d_mean_train_68 = data_walking_train68.mean()
d_mean_train_69 = data_walking_train69.mean()

# %%
array2 = [[(eval('d_min_train_'+str(x)))[1:],eval('d_max_train_'+str(x))[1:],eval('d_mean_train_'+str(x))[1:]] for x in range(1,70)]
#print array1[0]
#print eval('d_min_'+str(1))
print (d_min_train_60)
#print "hello"
#print array2[0]
print (array2[0])
print (len(array2))
print (type(array2[0]))
#print type(array1)
print (list(itertools.chain.from_iterable(array2[7])))
# Out:
# # Columns: time     0.00
# avg_rss12          21.50
# var_rss12           0.00
# avg_rss13           6.50
# var_rss13           0.00
# avg_rss23           6.33
# var_rss23           0.00
# dtype: float64
# [avg_rss12    35.0
# var_rss12     0.0
# avg_rss13     6.5
# var_rss13     0.0
# avg_rss23    29.0
# var_rss23     0.0
# dtype: float64, avg_rss12    47.40
# var_rss12     1.70
# avg_rss13    29.75
# var_rss13     4.44
# avg_rss23    38.50
# var_rss23     1.79
# dtype: float64, avg_rss12    43.954500
# var_rss12     0.426250
# avg_rss13    22.122354
# var_rss13     0.497313
# avg_rss23    35.588458
# var_rss23     0.493292
# dtype: float64]
# 69
# <type 'list'>
# [19.0, 0.0, 0.0, 0.0, 1.67, 0.0, 45.5, 6.4, 32.75, 11.42, 36.0, 6.73, 30.93810416666667, 0.4671666666666672, 14.589833333333333, 0.777541666666668, 18.38908333333333, 1.1073541666666684]

# %%
dataframe_train = pd.DataFrame(columns=total_columns)
dataframe_train.loc[0] = rows
print (dataframe_train)
dataframe_train.shape
# Out:
#    min_avg_rss12  min_var_rss12  min_avg_rss13  min_var_rss13  min_avg_rss23  \
# 0          37.25            0.0            4.0            0.0          27.25
#
#    min_var_rss23  max_avg_rss12  max_var_rss12  max_avg_rss13  max_var_rss13  \
# 0            0.0           45.0            1.3           29.5           7.23
#
#    max_avg_rss23  max_var_rss23  mean_avg_rss12  mean_var_rss12  \
# 0          38.25           1.92       40.624792        0.358604
#
#    mean_avg_rss13  mean_var_rss13  mean_avg_rss23  mean_var_rss23
# 0       19.040937        0.832542       34.311292        0.570583
# (1, 18)

# %%
import itertools
from IPython.display import display, HTML
for i in range(0,69):
    #print i
    dataframe_train.loc[i] = list(itertools.chain.from_iterable(array2[i]))
display(dataframe_train) 
dataframe_train.shape
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-809719acdc28> in <module>()
#       3 for i in range(0,69):
#       4     #print i
# ----> 5     dataframe_train.loc[i] = list(itertools.chain.from_iterable(array2[i]))
#       6 display(dataframe_train)
#       7 dataframe_train.shape
#
# c:\python27\lib\site-packages\pandas\core\indexing.pyc in __setitem__(self, key, value)
#     192             key = com._apply_if_callable(key, self.obj)
#     193         indexer = self._get_setitem_indexer(key)
# --> 194         self._setitem_with_indexer(indexer, value)
#     195
#     196     def _has_valid_type(self, k, axis):
#
# c:\python27\lib\site-packages\pandas\core\indexing.pyc in _setitem_with_indexer(self, indexer, value)
#     437                         if is_list_like_indexer(value):
#     438                             if len(value) != len(self.obj.columns):
# ...
