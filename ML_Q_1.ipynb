# %%
#!/usr/bin/env python -W ignore::DeprecationWarning
from scipy.stats import variation
from sklearn.linear_model import LinearRegression
import numpy as np
import matplotlib.pylab as plt
from sklearn import linear_model
import scipy  
import scikits.bootstrap as bootstrap
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.linear_model import Ridge,RidgeCV,Lasso,LassoCV
import pandas as pd
import pandas as pd
from ggplot import *
from scipy import stats
from sklearn.preprocessing import scale
from sklearn.decomposition import PCA
import seaborn as sns
# Out:
# c:\python27\lib\site-packages\ggplot\utils.py:81: FutureWarning: pandas.tslib is deprecated and will be removed in a future version.
# You can access Timestamp as pandas.Timestamp
#   pd.tslib.Timestamp,
# c:\python27\lib\site-packages\ggplot\stats\smoothers.py:4: FutureWarning: The pandas.lib module is deprecated and will be removed in a future version. These are private functions and can be accessed from pandas._libs.lib instead
#   from pandas.lib import Timestamp
# c:\python27\lib\site-packages\statsmodels\compat\pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
community = pd.read_csv('communities_data.csv',na_values='?')
column name = list(data)


data = data.drop(['state numeric','county numeric','community numeric','communityname string','fold numeric'], axis=1)
Finaldata = data.replace('?', np.NaN)

# %%
f, ax = plt.subplots(figsize=(25, 15))
corr = Finaldata.corr()
sns.heatmap(corr, mask=np.zeros_like(corr, dtype=np.bool), cmap=sns.diverging_palette(220, 10, as_cmap=True),
            square=True, ax=ax)

# %%
features_cov = []
for i in range(0,122):
    gg = data.iloc[:,i:i+1]
    gg=gg.values
    cov = variation(NaNdata[headers[6 + i]],axis=0)
    print cov
    features_cov.append(cov)
    
tf_cv = sum(features_cov, [])
tf_labels = headers[:-1]
# Out:
# 0.35292179679337704
# 1.4112970103505602
# 0.3238502683294552
# 1.3603869098203398
# 1.6141050556672718
# 0.36576666870694785
# 0.29081641328631874
# 0.49531880944774387
# 0.4233253442363529
# 2.0024356740953406
# 0.6385860830755095
# 0.5799397694972527
# 0.3278464057524231
# 0.699906048295189
# 0.35933454767955014
# 0.36822728826551365
# 0.6991293654212649
# 0.3494564370827332
# 0.5278226789518344
# 0.5458640979558119
# 0.5077519357725004
# 0.5897984804039423
# 0.8096900594385701
# 0.6063799715445065
# nan
# 0.4741855438499917
# 2.304572288592734
# 0.754032723919229
# 0.6751728865625166
# 0.5281366093094352
# 0.5784419894652018
# 0.5562057281023431
# 0.3474097975024348
# 0.5105927504831472
# 0.39786027692545534
# 0.5086092246435892
# 0.422174156915495
# 0.39508433692223927
# 0.40394633646357214
# 0.35891402522972676
# 0.3710113233197009
# 0.3167937683837806
# 0.33051105502492395
# 0.33243501582016527
# 0.3293966341259217
# 0.3284740058977256
# 0.33625037350111625
# ...

# %%
for i in tf_cv:
    x = features_cv[i] 
    y = predictors_data_goal_y_train
   
    x = x.to_frame()

    pp =pd.concat([x,y], axis=1)

    plt.scatter(x, y)
    g = sns.boxplot(pp)
  
    plt.show()

# %%
#LinearRegression
lm = LinearRegression()

lm.fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-34d8a6cab65a> in <module>()
#       2 lm = LinearRegression()
#       3
# ----> 4 lm.fit(x_train,y_train)
#
# c:\python27\lib\site-packages\sklearn\linear_model\base.pyc in fit(self, X, y, sample_weight)
#     480         n_jobs_ = self.n_jobs
#     481         X, y = check_X_y(X, y, accept_sparse=['csr', 'csc', 'coo'],
# --> 482                          y_numeric=True, multi_output=True)
#     483
#     484         if sample_weight is not None and np.atleast_1d(sample_weight).ndim > 1:
#
# c:\python27\lib\site-packages\sklearn\utils\validation.pyc in check_X_y(X, y, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
# ...

# %%
pred =lm.predict(x_test)
print("Mean squared error: %.2f"
      % mean_squared_error(y_test, pred))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-72426894c1dc> in <module>()
# ----> 1 pred =lm.predict(x_test)
#       2 print("Mean squared error: %.2f"
#       3       % mean_squared_error(y_test, pred))
#
# NameError: name 'x_test' is not defined

# %%
#RIDGE REGRESSION

ridge = linear_model.Ridge ()
ridge.fit (data_test,data_train) 
print "Ridge regression Coeff:  \n" + str(ridge.coef_)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-0df1278c6b35> in <module>()
#       2
#       3 reg_r = linear_model.Ridge ()
# ----> 4 reg_r.fit (data_test,data_train)
#       5 print "Ridge regression Coeff:  \n" + str(reg_r.coef_)
#
# NameError: name 'data_test' is not defined

# %%
# Lasso
lasso = Lasso(max_iter = 10000, normalize = False)
lasso2 = LassoCV(alphas = None, cv = 10, max_iter = 100000, normalize = False)
lasso2.fit(x_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-e4f93e5d85c5> in <module>()
#       2 la = Lasso(max_iter = 10000, normalize = False)
#       3 lacv = LassoCV(alphas = None, cv = 10, max_iter = 100000, normalize = False)
# ----> 4 lacv.fit(x_train, y_train)
#       5
#       6
#
# NameError: name 'y_train' is not defined

# %%
la.set_params(alpha=lassocv.alpha_)
la.fit(x_train, y_train)
y_pred_l = lasso.predict(x_test)

y_test = np.array(y_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-b777608c9955> in <module>()
# ----> 1 la.set_params(alpha=lassocv.alpha_)
#       2 la.fit(x_train, y_train)
#       3 y_pred_l = lasso.predict(x_test)
#       4
#       5 y_test = np.array(y_test)
#
# NameError: name 'lassocv' is not defined

# %%
#PCA
p = PCA()
PX = pca.fit_transform(scale(x_train))


np.cumsum(np.round(p.explained_variance_ratio_, decimals=4)*100)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-09bfdd94535d> in <module>()
#       1 #PCA
#       2 p = PCA()
# ----> 3 PX = pca.fit_transform(scale(x_train))
#       4
#       5
#
# NameError: name 'pca' is not defined

# %%
score = -1*cross_validation.cross_val_score(regr, np.ones((n,1)), y_train, cv=kf_10, scoring='neg_mean_squared_error').mean()    
mse.append(score)

# %%
for i in np.arange(1, 20):
    score = -1*model_selection.cross_val_score(regr, X_red[:,:i], y_train, cv=kf_10, scoring='neg_mean_squared_error').mean()
    mse.append(score)
print len(mse)
